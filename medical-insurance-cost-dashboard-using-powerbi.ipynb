# %% [markdown]
# <a href="https://www.kaggle.com/code/hidayah98/medical-insurance-cost-dashboard-using-powerbi?scriptVersionId=157893859" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # My First Power BI Project
#
# This notebook is my first project using Power BI. Here's the link to the GitHub repository:
# [Link to GitHub Project](https://github.com/hidayahkhamsani/Project)
#
# Feel free to check out the project for more details!
